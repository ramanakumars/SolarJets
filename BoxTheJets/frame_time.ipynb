# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from aggregation import Aggregator
plt.style.use('default')
from astropy.io import ascii

# %%
aggregator = Aggregator('reductions/point_reducer_hdbscan_box_the_jets.csv', 
                        'reductions/shape_reducer_hdbscan_box_the_jets.csv')

# %%
aggregator.load_extractor_data('extracts/point_extractor_by_frame_box_the_jets.csv',
                               'extracts/shape_extractor_rotateRectangle_box_the_jets.csv')

# %%
multijet_subjects = ascii.read('multiplejets_20220209.txt', format='fast_no_header')

# %%
for subject in multijet_subjects:
    points_datai = aggregator.points_data[:][(aggregator.points_data['subject_id']==subject[0])&(aggregator.points_data['task']=='T1')]
    print(points_datai)
    aggregator.plot_subject_both(subject[0])
# Out:
# subject_id workflow_id ... data.frame0.T5_tool1_clusters_var_x_y
# ---------- ----------- ... -------------------------------------
#   70444287       19650 ...                                    --
# subject_id workflow_id ... data.frame0.T5_tool1_clusters_var_x_y
# ---------- ----------- ... -------------------------------------
#   70444432       19650 ...                                    --
# subject_id workflow_id ... data.frame0.T5_tool1_clusters_var_x_y
# ---------- ----------- ... -------------------------------------
#   70446217       19650 ...                                    --
# subject_id workflow_id ... data.frame0.T5_tool1_clusters_var_x_y
# ---------- ----------- ... -------------------------------------
#   70446417       19650 ...                                    --
# subject_id workflow_id ... data.frame0.T5_tool1_clusters_var_x_y
# ---------- ----------- ... -------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4248/4003420000.py in <module>
#       2     points_datai = aggregator.points_data[:][(aggregator.points_data['subject_id']==subject[0])&(aggregator.points_data['task']=='T1')]
#       3     print(points_datai)
# ----> 4     aggregator.plot_subject_both(subject[0])
#
# D:\Research\zooniverse\projects\SolarJets\BoxTheJets\aggregation\workflow.py in plot_subject_both(self, subject)
#     183         fig, ax = plt.subplots(1,1, dpi=150)
#     184
# --> 185         self.plot_subject(subject, 'T1', ax)
#     186         self.plot_subject(subject, 'T5', ax)
#     187
#
# D:\Research\zooniverse\projects\SolarJets\BoxTheJets\aggregation\workflow.py in plot_subject(self, subject, task, ax)
#     197         # convert the data from the csv into an array
#     198         try:
# --> 199             x0_i = ast.literal_eval(points_datai[f'data.frame0.{task}_tool0_points_x'][0])
#     200             y0_i = ast.literal_eval(points_datai[f'data.frame0.{task}_tool0_points_y'][0])
#     201         except ValueError:
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins._MaskedColumnGetitemShim.__getitem__()
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins.masked_column_getitem()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3218         # mask of being reshaped if it hasn't been set up properly yet
#    3219         # So it's easier to stick to the current version
# -> 3220         dout = self.data[indx]
#    3221         _mask = self._mask
#    3222
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3218         # mask of being reshaped if it hasn't been set up properly yet
#    3219         # So it's easier to stick to the current version
# -> 3220         dout = self.data[indx]
#    3221         _mask = self._mask
#    3222
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
aggregator.load_classification_data()

# %%
aggregator.get_retired_subjects()
# Out:
# 1217
#  [=================== ] 1217/1217

# %%
for subject in multijet_subjects:
    aggregator.plot_frame_info(subject[0], task='T1')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4248/3054204518.py in <module>
#       1 for subject in multijet_subjects:
# ----> 2     aggregator.plot_frame_info(subject[0], task='T1')
#
# D:\Research\zooniverse\projects\SolarJets\BoxTheJets\aggregation\workflow.py in plot_frame_info(self, subject, task)
#     522             plot the distribution of classifications by frame time
#     523         '''
# --> 524         base_points = self.get_frame_time_base(subject, task)
#     525         box         = self.get_frame_time_box(subject, task)
#     526
#
# D:\Research\zooniverse\projects\SolarJets\BoxTheJets\aggregation\workflow.py in get_frame_time_base(self, subject, task)
#     344         points_datai = self.points_data[:][(self.points_data['subject_id']==subject)&(self.points_data['task']==task)]
#     345         try:
# --> 346             cx0_i = np.asarray(ast.literal_eval(points_datai[f'data.frame0.{task}_tool0_clusters_x'][0]))
#     347             cy0_i = np.asarray(ast.literal_eval(points_datai[f'data.frame0.{task}_tool0_clusters_y'][0]))
#     348             x0_i  = np.asarray(ast.literal_eval(points_datai[f'data.frame0.{task}_tool0_points_x'][0]))
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins._MaskedColumnGetitemShim.__getitem__()
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy\table\_column_mixins.pyx in astropy.table._column_mixins.masked_column_getitem()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3218         # mask of being reshaped if it hasn't been set up properly yet
#    3219         # So it's easier to stick to the current version
# -> 3220         dout = self.data[indx]
#    3221         _mask = self._mask
#    3222
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3218         # mask of being reshaped if it hasn't been set up properly yet
#    3219         # So it's easier to stick to the current version
# -> 3220         dout = self.data[indx]
#    3221         _mask = self._mask
#    3222
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for subject in aggregator.retired_subjects:
    aggregator.plot_frame_info(subject, 'T1')
