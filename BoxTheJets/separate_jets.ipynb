# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from aggregation import Aggregator
from astropy.io import ascii
from astropy.table import Table
import numpy as np
plt.style.use('default')
# Out:
# Broken libmagic installation detected. The python-magic module is installed but can't be imported. Please check that both python-magic and the libmagic shared library are installed correctly. Uploading media other than images may not work.

# %%
aggregator        = Aggregator('reductions/point_reducer_hdbscan_box_the_jets.csv', 
                               'reductions/shape_reducer_hdbscan_box_the_jets.csv')

# %%
multijet_subjects = ascii.read('multiplejets_20220209.txt', format='fast_no_header')

# %%
for subject in multijet_subjects:
    subject = subject[0]
    data_T1, clusters_T1 = aggregator.get_box_data(subject, 'T1')
    _, _, box_iou_T1     = aggregator.get_cluster_confidence(subject, 'T1')
    print(box_iou_T1)
    data_T5, clusters_T5 = aggregator.get_box_data(subject, 'T5')
    _, _, box_iou_T5     = aggregator.get_cluster_confidence(subject, 'T5')
    print(box_iou_T5)
    aggregator.find_unique_jets(subject, clip_iou=0.3)
    
    aggregator.plot_subject_both(subject)
# Out:
# [0.67637011 0.25271287]
# [0.63270888]
# 0.0 [0.6763701125186886, 0.25271286727761005]
# 0.0 [0.6763701125186886, 0.6327088786412599]
# 0.593275287927402 [0.25271286727761005, 0.6327088786412599]
# [0.41393951]
# [0.23257105]
# 0.10630824115302728 [0.41393950667765544, 0.23257105491230265]
# [0.54616743]
# [0.64888772]
# 0.0 [0.5461674337745686, 0.6488877234145818]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12492/4244866987.py in <module>
#       9     aggregator.find_unique_jets(subject, clip_iou=0.3)
#      10
# ---> 11     aggregator.plot_subject_both(subject)
#
# D:\Research\zooniverse\projects\SolarJets\BoxTheJets\aggregation\workflow.py in plot_subject_both(self, subject)
#     184
#     185         self.plot_subject(subject, 'T1', ax)
# --> 186         self.plot_subject(subject, 'T5', ax)
#     187
# ...
